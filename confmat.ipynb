# %% [markdown]
# # Matriz de confusão

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Imports

# %%
from IPython.core.display import display, HTML

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.linear_model import LogisticRegression
from sklearn import datasets
from sklearn import metrics
from sklearn.preprocessing import binarize

from skanalytics.reporting.binary_confusion_matrix import BinaryConfusionMatrix

# %% [markdown]
# # Modelo de exemplo

# %%
X, y = datasets.make_classification(n_samples=100000, n_features=20,
                                    n_informative=2, n_redundant=2)

train_samples = 100  # Samples used for training the models

X_train = X[:train_samples]
X_test = X[train_samples:]
y_train = y[:train_samples]
y_test = y[train_samples:]

lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# # Criação de matriz de confusão

# %%
cm = BinaryConfusionMatrix(y_test, lr.predict(X_test))

# %% [markdown]
# ## Padrão

# %%
HTML(cm.html())
# Out:
#         <table align="center" valign="center" style="text-align:center; border:none; background:transparent;">
#         <tr>
#             <td style="border:none;" colspan="2"></td>
#             <td style="text-align:center;background:#eeeebb;vertical-align: middle" colspan="2">
#                 <b>True Condition</b>
#             </td>
#             <td style="background:none;" colspan="3"></td>
#         </tr>
#         <tr>
#             <td style="border:none;"></td>
#             <td style="background:#dddddd;text-align: center;vertical-align: middle">Total Population <br/ >99,900</td>
#             <td style="background:#ffffcc;text-align: center;vertical-align: middle">Condition Positive (CP) <br/ >49,957</td>
#             <td style="background:#ddddaa;text-align: center;vertical-align: middle">Condition Negative (CN) <br/ >49,943</td>
#             <td style="background:#eeeecc;text-align: center;vertical-align: middle">Prevalence
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣCP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             Total
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >50.0%</td>
#             <td style="background:#cceecc;border-left:double silver;text-align: center" colspan="2">
#                 Accuracy
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#
#         ΣTP
#         &#160;+&#160;
#         ΣTN
#
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             Total
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >94.3%
#             </td>
#         </tr>
#         <tr>
#             <td style="background:#bbeeee;text-align: center;vertical-align: middle;" rowspan="2">
#                 <b>Predicted<br />Condition</b>
#             </td>
#             <td style="background:#ccffff;text-align: center;vertical-align: middle">Predicted Condition<br />Positive (PCP) <br/ >48,183</td>
#             <td style="background:#ccffcc;text-align: center;vertical-align: middle"><span style="color:#006600"><b>True Positive (TP)</b></span><br /> <br/ >46,201</td>
#             <td style="background:#eedddd;text-align: center;vertical-align: middle"><span style="color:#cc0000"><b>False Positive (FP)</b><br />Type I error</span><br /> <br/ >1,982</td>
#             <td style="background:#ccffee;border-top:double silver;text-align: center;vertical-align: middle">
#                 Positive Predictive Value (PPV)
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣTP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣPCP
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >95.9%
#             </td>
#             <td style="background:#cceeff;border-top:double silver;text-align: center" colspan="2">
#                 False Discovery Rate (FDR)
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣFP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣPCP
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >4.1%
#             </td>
#         </tr>
#         <tr>
#             <td style="background:#aadddd;text-align: center;vertical-align: middle">Predicted Condition<br />Negative (PCN) <br/ >51,717</td>
#             <td style="background:#ffdddd;text-align: center;vertical-align: middle"><span style="color:#cc0000;"><b>False Negative (FN)</b><br />Type II error</span><br /> <br/ >3,756</td>
#             <td style="background:#bbeebb;text-align: center;vertical-align: middle"><span style="color:#006600;"><b>True Negative (TN)</b></span><br /> <br/ >47,961</td>
#             <td style="background:#eeddee;border-bottom:double silver;text-align: center;vertical-align: middle">
#                 False Omission Rate (FOR)
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣFN
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣPCN
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >7.3%
#             </td>
#             <td style="background:#aaddcc;border-bottom:double silver;text-align: center" colspan="2">
#                 Negative Predictive Value (NPV)
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣTN
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣPCN
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >92.7%
#             </td>
#         </tr>
#         <tr style="font-size:90%;">
#             <td style="border:none;vertical-align:bottom;padding:0 2px 0 0;color:#999999;text-align: center" colspan="2" rowspan="2">
#                 <div style="height: 105px; width: 210px"><img alt="DiagnosticTesting Diagram.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0e/DiagnosticTesting_Diagram.svg/210px-DiagnosticTesting_Diagram.svg.png" width="210" height="105" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0e/DiagnosticTesting_Diagram.svg/315px-DiagnosticTesting_Diagram.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0e/DiagnosticTesting_Diagram.svg/420px-DiagnosticTesting_Diagram.svg.png 2x" data-file-width="512" data-file-height="256" /></div>
#             </td>
#             <td style="background:#eeffcc;text-align: center;vertical-align: middle">True Positive Rate (TPR)
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣTP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣCP
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >92.5%</td>
#             <td style="background:#eeddbb;text-align: center;vertical-align: middle">False Positive Rate (FPR)
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣFP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣCN
#           </span>

# %% [markdown]
# ## Sem rótulos

# %%
HTML(cm.html(label=False))
# Out:
#         <table align="center" valign="center" style="text-align:center; border:none; background:transparent;">
#         <tr>
#             <td style="border:none;" colspan="2"></td>
#             <td style="text-align:center;background:#eeeebb;vertical-align: middle" colspan="2">
#                 <b>True Condition</b>
#             </td>
#             <td style="background:none;" colspan="3"></td>
#         </tr>
#         <tr>
#             <td style="border:none;"></td>
#             <td style="background:#dddddd;text-align: center;vertical-align: middle"><b>Total</b> <br/ >99,900</td>
#             <td style="background:#ffffcc;text-align: center;vertical-align: middle"><b>CP</b> <br/ >49,957</td>
#             <td style="background:#ddddaa;text-align: center;vertical-align: middle"><b>CN</b> <br/ >49,943</td>
#             <td style="background:#eeeecc;text-align: center;vertical-align: middle"><b>Prev</b>
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣCP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             Total
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >50.0%</td>
#             <td style="background:#cceecc;border-left:double silver;text-align: center" colspan="2">
#                 <b>Acc</b>
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#
#         ΣTP
#         &#160;+&#160;
#         ΣTN
#
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             Total
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >94.3%
#             </td>
#         </tr>
#         <tr>
#             <td style="background:#bbeeee;text-align: center;vertical-align: middle;" rowspan="2">
#                 <b>Predicted<br />Condition</b>
#             </td>
#             <td style="background:#ccffff;text-align: center;vertical-align: middle"><b>PCP</b> <br/ >48,183</td>
#             <td style="background:#ccffcc;text-align: center;vertical-align: middle"><b>TP</b> <br/ >46,201</td>
#             <td style="background:#eedddd;text-align: center;vertical-align: middle"><b>FP</b> <br/ >1,982</td>
#             <td style="background:#ccffee;border-top:double silver;text-align: center;vertical-align: middle">
#                 <b>PPV</b>
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣTP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣPCP
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >95.9%
#             </td>
#             <td style="background:#cceeff;border-top:double silver;text-align: center" colspan="2">
#                 <b>FDR</b>
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣFP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣPCP
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >4.1%
#             </td>
#         </tr>
#         <tr>
#             <td style="background:#aadddd;text-align: center;vertical-align: middle"><b>PCN</b> <br/ >51,717</td>
#             <td style="background:#ffdddd;text-align: center;vertical-align: middle"><b>FN</b> <br/ >3,756</td>
#             <td style="background:#bbeebb;text-align: center;vertical-align: middle"><b>TN</b> <br/ >47,961</td>
#             <td style="background:#eeddee;border-bottom:double silver;text-align: center;vertical-align: middle">
#                 <b>FOR</b>
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣFN
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣPCN
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >7.3%
#             </td>
#             <td style="background:#aaddcc;border-bottom:double silver;text-align: center" colspan="2">
#                 <b>NPV</b>
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣTN
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣPCN
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >92.7%
#             </td>
#         </tr>
#         <tr style="font-size:90%;">
#             <td style="border:none;vertical-align:bottom;padding:0 2px 0 0;color:#999999;text-align: center" colspan="2" rowspan="2">
#                 <div style="height: 105px; width: 210px"><img alt="DiagnosticTesting Diagram.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0e/DiagnosticTesting_Diagram.svg/210px-DiagnosticTesting_Diagram.svg.png" width="210" height="105" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0e/DiagnosticTesting_Diagram.svg/315px-DiagnosticTesting_Diagram.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0e/DiagnosticTesting_Diagram.svg/420px-DiagnosticTesting_Diagram.svg.png 2x" data-file-width="512" data-file-height="256" /></div>
#             </td>
#             <td style="background:#eeffcc;text-align: center;vertical-align: middle"><b>TPR</b>
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣTP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣCP
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >92.5%</td>
#             <td style="background:#eeddbb;text-align: center;vertical-align: middle"><b>FPR</b>
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣFP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣCN
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >4.0%</td>
#             <td style="background:#eeeeee;text-align: center;vertical-align: middle"><b>PLR</b>
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣTPR
#           </span>
#           <sp

# %% [markdown]
# ## Sem rótulos e sem legenda

# %%
HTML(cm.html(label=False, legend=False))
# Out:
#         <table align="center" valign="center" style="text-align:center; border:none; background:transparent;">
#         <tr>
#             <td style="border:none;" colspan="2"></td>
#             <td style="text-align:center;background:#eeeebb;vertical-align: middle" colspan="2">
#                 <b>True Condition</b>
#             </td>
#             <td style="background:none;" colspan="3"></td>
#         </tr>
#         <tr>
#             <td style="border:none;"></td>
#             <td style="background:#dddddd;text-align: center;vertical-align: middle"><b>Total</b> <br/ >99,900</td>
#             <td style="background:#ffffcc;text-align: center;vertical-align: middle"><b>CP</b> <br/ >49,957</td>
#             <td style="background:#ddddaa;text-align: center;vertical-align: middle"><b>CN</b> <br/ >49,943</td>
#             <td style="background:#eeeecc;text-align: center;vertical-align: middle"><b>Prev</b>
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣCP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             Total
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >50.0%</td>
#             <td style="background:#cceecc;border-left:double silver;text-align: center" colspan="2">
#                 <b>Acc</b>
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#
#         ΣTP
#         &#160;+&#160;
#         ΣTN
#
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             Total
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >94.3%
#             </td>
#         </tr>
#         <tr>
#             <td style="background:#bbeeee;text-align: center;vertical-align: middle;" rowspan="2">
#                 <b>Predicted<br />Condition</b>
#             </td>
#             <td style="background:#ccffff;text-align: center;vertical-align: middle"><b>PCP</b> <br/ >48,183</td>
#             <td style="background:#ccffcc;text-align: center;vertical-align: middle"><b>TP</b> <br/ >46,201</td>
#             <td style="background:#eedddd;text-align: center;vertical-align: middle"><b>FP</b> <br/ >1,982</td>
#             <td style="background:#ccffee;border-top:double silver;text-align: center;vertical-align: middle">
#                 <b>PPV</b>
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣTP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣPCP
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >95.9%
#             </td>
#             <td style="background:#cceeff;border-top:double silver;text-align: center" colspan="2">
#                 <b>FDR</b>
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣFP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣPCP
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >4.1%
#             </td>
#         </tr>
#         <tr>
#             <td style="background:#aadddd;text-align: center;vertical-align: middle"><b>PCN</b> <br/ >51,717</td>
#             <td style="background:#ffdddd;text-align: center;vertical-align: middle"><b>FN</b> <br/ >3,756</td>
#             <td style="background:#bbeebb;text-align: center;vertical-align: middle"><b>TN</b> <br/ >47,961</td>
#             <td style="background:#eeddee;border-bottom:double silver;text-align: center;vertical-align: middle">
#                 <b>FOR</b>
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣFN
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣPCN
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >7.3%
#             </td>
#             <td style="background:#aaddcc;border-bottom:double silver;text-align: center" colspan="2">
#                 <b>NPV</b>
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣTN
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣPCN
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >92.7%
#             </td>
#         </tr>
#         <tr style="font-size:90%;">
#             <td style="border:none;vertical-align:bottom;padding:0 2px 0 0;color:#999999;text-align: center" colspan="2" rowspan="2">
#
#             </td>
#             <td style="background:#eeffcc;text-align: center;vertical-align: middle"><b>TPR</b>
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣTP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣCP
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >92.5%</td>
#             <td style="background:#eeddbb;text-align: center;vertical-align: middle"><b>FPR</b>
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣFP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣCN
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >4.0%</td>
#             <td style="background:#eeeeee;text-align: center;vertical-align: middle"><b>PLR</b>
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣTPR
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣFPR
#           </span>
#         </span>
#     </span>
#
#     </span> <br/ >23.304</td>
#             <td style="background:#dddddd;text-align: center;vertical-align: middle"" rowspan="2">
#                 <b>DOR</b>
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:bloc

# %% [markdown]
# ## Sem rótulos e equações

# %%
HTML(cm.html(label=False, equation=False))
# Out:
#         <table align="center" valign="center" style="text-align:center; border:none; background:transparent;">
#         <tr>
#             <td style="border:none;" colspan="2"></td>
#             <td style="text-align:center;background:#eeeebb;vertical-align: middle" colspan="2">
#                 <b>True Condition</b>
#             </td>
#             <td style="background:none;" colspan="3"></td>
#         </tr>
#         <tr>
#             <td style="border:none;"></td>
#             <td style="background:#dddddd;text-align: center;vertical-align: middle"><b>Total</b> <br/ >99,900</td>
#             <td style="background:#ffffcc;text-align: center;vertical-align: middle"><b>CP</b> <br/ >49,957</td>
#             <td style="background:#ddddaa;text-align: center;vertical-align: middle"><b>CN</b> <br/ >49,943</td>
#             <td style="background:#eeeecc;text-align: center;vertical-align: middle"><b>Prev</b> <br/ >50.0%</td>
#             <td style="background:#cceecc;border-left:double silver;text-align: center" colspan="2">
#                 <b>Acc</b> <br/ >94.3%
#             </td>
#         </tr>
#         <tr>
#             <td style="background:#bbeeee;text-align: center;vertical-align: middle;" rowspan="2">
#                 <b>Predicted<br />Condition</b>
#             </td>
#             <td style="background:#ccffff;text-align: center;vertical-align: middle"><b>PCP</b> <br/ >48,183</td>
#             <td style="background:#ccffcc;text-align: center;vertical-align: middle"><b>TP</b> <br/ >46,201</td>
#             <td style="background:#eedddd;text-align: center;vertical-align: middle"><b>FP</b> <br/ >1,982</td>
#             <td style="background:#ccffee;border-top:double silver;text-align: center;vertical-align: middle">
#                 <b>PPV</b> <br/ >95.9%
#             </td>
#             <td style="background:#cceeff;border-top:double silver;text-align: center" colspan="2">
#                 <b>FDR</b> <br/ >4.1%
#             </td>
#         </tr>
#         <tr>
#             <td style="background:#aadddd;text-align: center;vertical-align: middle"><b>PCN</b> <br/ >51,717</td>
#             <td style="background:#ffdddd;text-align: center;vertical-align: middle"><b>FN</b> <br/ >3,756</td>
#             <td style="background:#bbeebb;text-align: center;vertical-align: middle"><b>TN</b> <br/ >47,961</td>
#             <td style="background:#eeddee;border-bottom:double silver;text-align: center;vertical-align: middle">
#                 <b>FOR</b> <br/ >7.3%
#             </td>
#             <td style="background:#aaddcc;border-bottom:double silver;text-align: center" colspan="2">
#                 <b>NPV</b> <br/ >92.7%
#             </td>
#         </tr>
#         <tr style="font-size:90%;">
#             <td style="border:none;vertical-align:bottom;padding:0 2px 0 0;color:#999999;text-align: center" colspan="2" rowspan="2">
#                 <div style="height: 105px; width: 210px"><img alt="DiagnosticTesting Diagram.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0e/DiagnosticTesting_Diagram.svg/210px-DiagnosticTesting_Diagram.svg.png" width="210" height="105" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0e/DiagnosticTesting_Diagram.svg/315px-DiagnosticTesting_Diagram.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0e/DiagnosticTesting_Diagram.svg/420px-DiagnosticTesting_Diagram.svg.png 2x" data-file-width="512" data-file-height="256" /></div>
#             </td>
#             <td style="background:#eeffcc;text-align: center;vertical-align: middle"><b>TPR</b> <br/ >92.5%</td>
#             <td style="background:#eeddbb;text-align: center;vertical-align: middle"><b>FPR</b> <br/ >4.0%</td>
#             <td style="background:#eeeeee;text-align: center;vertical-align: middle"><b>PLR</b> <br/ >23.304</td>
#             <td style="background:#dddddd;text-align: center;vertical-align: middle"" rowspan="2">
#                 <b>DOR</b> <br/ >297.653
#             </td>
#             <td style="background:#ddffdd;border-left:double silver;line-height:2;text-align: center;vertical-align: middle"" rowspan="2">
#                 <b>F<sub>1</sub></b> <br/ >94.2%
#             </td>
#         </tr>
#         <tr style="font-size:90%;text-align: center;vertical-align: middle">
#             <td style="background:#ffeecc;text-align: center;vertical-align: middle">
#                 <b>FNR</b> <br/ >7.5%
#             </td>
#             <td style="background:#ddeebb;text-align: center;vertical-align: middle">
#                 <b>TNR</b> <br/ >96.0%
#             </td>
#             <td style="background:#cccccc;text-align: center;vertical-align: middle">
#                 <b>NLR</b> <br/ >0.078
#             </td>
#         </tr>
#         </table>

# %% [markdown]
# ## Sem rótulos, sem equações e sem legenda

# %%
HTML(cm.html(label=False, equation=False, legend=False))
# Out:
#         <table align="center" valign="center" style="text-align:center; border:none; background:transparent;">
#         <tr>
#             <td style="border:none;" colspan="2"></td>
#             <td style="text-align:center;background:#eeeebb;vertical-align: middle" colspan="2">
#                 <b>True Condition</b>
#             </td>
#             <td style="background:none;" colspan="3"></td>
#         </tr>
#         <tr>
#             <td style="border:none;"></td>
#             <td style="background:#dddddd;text-align: center;vertical-align: middle"><b>Total</b> <br/ >99,900</td>
#             <td style="background:#ffffcc;text-align: center;vertical-align: middle"><b>CP</b> <br/ >49,957</td>
#             <td style="background:#ddddaa;text-align: center;vertical-align: middle"><b>CN</b> <br/ >49,943</td>
#             <td style="background:#eeeecc;text-align: center;vertical-align: middle"><b>Prev</b> <br/ >50.0%</td>
#             <td style="background:#cceecc;border-left:double silver;text-align: center" colspan="2">
#                 <b>Acc</b> <br/ >94.3%
#             </td>
#         </tr>
#         <tr>
#             <td style="background:#bbeeee;text-align: center;vertical-align: middle;" rowspan="2">
#                 <b>Predicted<br />Condition</b>
#             </td>
#             <td style="background:#ccffff;text-align: center;vertical-align: middle"><b>PCP</b> <br/ >48,183</td>
#             <td style="background:#ccffcc;text-align: center;vertical-align: middle"><b>TP</b> <br/ >46,201</td>
#             <td style="background:#eedddd;text-align: center;vertical-align: middle"><b>FP</b> <br/ >1,982</td>
#             <td style="background:#ccffee;border-top:double silver;text-align: center;vertical-align: middle">
#                 <b>PPV</b> <br/ >95.9%
#             </td>
#             <td style="background:#cceeff;border-top:double silver;text-align: center" colspan="2">
#                 <b>FDR</b> <br/ >4.1%
#             </td>
#         </tr>
#         <tr>
#             <td style="background:#aadddd;text-align: center;vertical-align: middle"><b>PCN</b> <br/ >51,717</td>
#             <td style="background:#ffdddd;text-align: center;vertical-align: middle"><b>FN</b> <br/ >3,756</td>
#             <td style="background:#bbeebb;text-align: center;vertical-align: middle"><b>TN</b> <br/ >47,961</td>
#             <td style="background:#eeddee;border-bottom:double silver;text-align: center;vertical-align: middle">
#                 <b>FOR</b> <br/ >7.3%
#             </td>
#             <td style="background:#aaddcc;border-bottom:double silver;text-align: center" colspan="2">
#                 <b>NPV</b> <br/ >92.7%
#             </td>
#         </tr>
#         <tr style="font-size:90%;">
#             <td style="border:none;vertical-align:bottom;padding:0 2px 0 0;color:#999999;text-align: center" colspan="2" rowspan="2">
#
#             </td>
#             <td style="background:#eeffcc;text-align: center;vertical-align: middle"><b>TPR</b> <br/ >92.5%</td>
#             <td style="background:#eeddbb;text-align: center;vertical-align: middle"><b>FPR</b> <br/ >4.0%</td>
#             <td style="background:#eeeeee;text-align: center;vertical-align: middle"><b>PLR</b> <br/ >23.304</td>
#             <td style="background:#dddddd;text-align: center;vertical-align: middle"" rowspan="2">
#                 <b>DOR</b> <br/ >297.653
#             </td>
#             <td style="background:#ddffdd;border-left:double silver;line-height:2;text-align: center;vertical-align: middle"" rowspan="2">
#                 <b>F<sub>1</sub></b> <br/ >94.2%
#             </td>
#         </tr>
#         <tr style="font-size:90%;text-align: center;vertical-align: middle">
#             <td style="background:#ffeecc;text-align: center;vertical-align: middle">
#                 <b>FNR</b> <br/ >7.5%
#             </td>
#             <td style="background:#ddeebb;text-align: center;vertical-align: middle">
#                 <b>TNR</b> <br/ >96.0%
#             </td>
#             <td style="background:#cccccc;text-align: center;vertical-align: middle">
#                 <b>NLR</b> <br/ >0.078
#             </td>
#         </tr>
#         </table>

# %% [markdown]
# ## Mínimo possível

# %%
HTML(cm.html(label=False, acronym=False, equation=False, legend=False))
# Out:
#         <table align="center" valign="center" style="text-align:center; border:none; background:transparent;">
#         <tr>
#             <td style="border:none;" colspan="2"></td>
#             <td style="text-align:center;background:#eeeebb;vertical-align: middle" colspan="2">
#                 <b>True Condition</b>
#             </td>
#             <td style="background:none;" colspan="3"></td>
#         </tr>
#         <tr>
#             <td style="border:none;"></td>
#             <td style="background:#dddddd;text-align: center;vertical-align: middle">99,900</td>
#             <td style="background:#ffffcc;text-align: center;vertical-align: middle">49,957</td>
#             <td style="background:#ddddaa;text-align: center;vertical-align: middle">49,943</td>
#             <td style="background:#eeeecc;text-align: center;vertical-align: middle">50.0%</td>
#             <td style="background:#cceecc;border-left:double silver;text-align: center" colspan="2">
#                 94.3%
#             </td>
#         </tr>
#         <tr>
#             <td style="background:#bbeeee;text-align: center;vertical-align: middle;" rowspan="2">
#                 <b>Predicted<br />Condition</b>
#             </td>
#             <td style="background:#ccffff;text-align: center;vertical-align: middle">48,183</td>
#             <td style="background:#ccffcc;text-align: center;vertical-align: middle">46,201</td>
#             <td style="background:#eedddd;text-align: center;vertical-align: middle">1,982</td>
#             <td style="background:#ccffee;border-top:double silver;text-align: center;vertical-align: middle">
#                 95.9%
#             </td>
#             <td style="background:#cceeff;border-top:double silver;text-align: center" colspan="2">
#                 4.1%
#             </td>
#         </tr>
#         <tr>
#             <td style="background:#aadddd;text-align: center;vertical-align: middle">51,717</td>
#             <td style="background:#ffdddd;text-align: center;vertical-align: middle">3,756</td>
#             <td style="background:#bbeebb;text-align: center;vertical-align: middle">47,961</td>
#             <td style="background:#eeddee;border-bottom:double silver;text-align: center;vertical-align: middle">
#                 7.3%
#             </td>
#             <td style="background:#aaddcc;border-bottom:double silver;text-align: center" colspan="2">
#                 92.7%
#             </td>
#         </tr>
#         <tr style="font-size:90%;">
#             <td style="border:none;vertical-align:bottom;padding:0 2px 0 0;color:#999999;text-align: center" colspan="2" rowspan="2">
#
#             </td>
#             <td style="background:#eeffcc;text-align: center;vertical-align: middle">92.5%</td>
#             <td style="background:#eeddbb;text-align: center;vertical-align: middle">4.0%</td>
#             <td style="background:#eeeeee;text-align: center;vertical-align: middle">23.304</td>
#             <td style="background:#dddddd;text-align: center;vertical-align: middle"" rowspan="2">
#                 297.653
#             </td>
#             <td style="background:#ddffdd;border-left:double silver;line-height:2;text-align: center;vertical-align: middle"" rowspan="2">
#                 94.2%
#             </td>
#         </tr>
#         <tr style="font-size:90%;text-align: center;vertical-align: middle">
#             <td style="background:#ffeecc;text-align: center;vertical-align: middle">
#                 7.5%
#             </td>
#             <td style="background:#ddeebb;text-align: center;vertical-align: middle">
#                 96.0%
#             </td>
#             <td style="background:#cccccc;text-align: center;vertical-align: middle">
#                 0.078
#             </td>
#         </tr>
#         </table>

# %% [markdown]
# # Apenas a tabela, sem valores

# %% [markdown]
# Útil para fazer consulta ou deixar os nomes separados.

# %%
HTML(cm.html(value=False))
# Out:
#         <table align="center" valign="center" style="text-align:center; border:none; background:transparent;">
#         <tr>
#             <td style="border:none;" colspan="2"></td>
#             <td style="text-align:center;background:#eeeebb;vertical-align: middle" colspan="2">
#                 <b>True Condition</b>
#             </td>
#             <td style="background:none;" colspan="3"></td>
#         </tr>
#         <tr>
#             <td style="border:none;"></td>
#             <td style="background:#dddddd;text-align: center;vertical-align: middle">Total Population</td>
#             <td style="background:#ffffcc;text-align: center;vertical-align: middle">Condition Positive (CP)</td>
#             <td style="background:#ddddaa;text-align: center;vertical-align: middle">Condition Negative (CN)</td>
#             <td style="background:#eeeecc;text-align: center;vertical-align: middle">Prevalence
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣCP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             Total
#           </span>
#         </span>
#     </span>
#
#     </span></td>
#             <td style="background:#cceecc;border-left:double silver;text-align: center" colspan="2">
#                 Accuracy
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#
#         ΣTP
#         &#160;+&#160;
#         ΣTN
#
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             Total
#           </span>
#         </span>
#     </span>
#
#     </span>
#             </td>
#         </tr>
#         <tr>
#             <td style="background:#bbeeee;text-align: center;vertical-align: middle;" rowspan="2">
#                 <b>Predicted<br />Condition</b>
#             </td>
#             <td style="background:#ccffff;text-align: center;vertical-align: middle">Predicted Condition<br />Positive (PCP)</td>
#             <td style="background:#ccffcc;text-align: center;vertical-align: middle"><span style="color:#006600"><b>True Positive (TP)</b></span><br /></td>
#             <td style="background:#eedddd;text-align: center;vertical-align: middle"><span style="color:#cc0000"><b>False Positive (FP)</b><br />Type I error</span><br /></td>
#             <td style="background:#ccffee;border-top:double silver;text-align: center;vertical-align: middle">
#                 Positive Predictive Value (PPV)
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣTP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣPCP
#           </span>
#         </span>
#     </span>
#
#     </span>
#             </td>
#             <td style="background:#cceeff;border-top:double silver;text-align: center" colspan="2">
#                 False Discovery Rate (FDR)
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣFP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣPCP
#           </span>
#         </span>
#     </span>
#
#     </span>
#             </td>
#         </tr>
#         <tr>
#             <td style="background:#aadddd;text-align: center;vertical-align: middle">Predicted Condition<br />Negative (PCN)</td>
#             <td style="background:#ffdddd;text-align: center;vertical-align: middle"><span style="color:#cc0000;"><b>False Negative (FN)</b><br />Type II error</span><br /></td>
#             <td style="background:#bbeebb;text-align: center;vertical-align: middle"><span style="color:#006600;"><b>True Negative (TN)</b></span><br /></td>
#             <td style="background:#eeddee;border-bottom:double silver;text-align: center;vertical-align: middle">
#                 False Omission Rate (FOR)
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣFN
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣPCN
#           </span>
#         </span>
#     </span>
#
#     </span>
#             </td>
#             <td style="background:#aaddcc;border-bottom:double silver;text-align: center" colspan="2">
#                 Negative Predictive Value (NPV)
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣTN
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣPCN
#           </span>
#         </span>
#     </span>
#
#     </span>
#             </td>
#         </tr>
#         <tr style="font-size:90%;">
#             <td style="border:none;vertical-align:bottom;padding:0 2px 0 0;color:#999999;text-align: center" colspan="2" rowspan="2">
#                 <div style="height: 105px; width: 210px"><img alt="DiagnosticTesting Diagram.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0e/DiagnosticTesting_Diagram.svg/210px-DiagnosticTesting_Diagram.svg.png" width="210" height="105" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0e/DiagnosticTesting_Diagram.svg/315px-DiagnosticTesting_Diagram.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0e/DiagnosticTesting_Diagram.svg/420px-DiagnosticTesting_Diagram.svg.png 2x" data-file-width="512" data-file-height="256" /></div>
#             </td>
#             <td style="background:#eeffcc;text-align: center;vertical-align: middle">True Positive Rate (TPR)
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣTP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣCP
#           </span>
#         </span>
#     </span>
#
#     </span></td>
#             <td style="background:#eeddbb;text-align: center;vertical-align: middle">False Positive Rate (FPR)
#     <span style="white-space:nowrap">
#         =
#     <span style="font-size:85%;white-space:nowrap;text-align:center">
#       <span style="display:inline-block; vertical-align:-0.5em;">
#           <span style="display:block; line-height:1em; margin:0 0.1em;">
#             ΣFP
#           </span>
#           <span style="display:block; line-height:1em; margin:0 0.1em;
#                        border-top:1px solid;">
#             ΣCN
#           </span>
#         </span>
#     </span>
#
#     </span></td>
#             <td style="background:#eeeeee;text-align: center;vertical-align: middle">Positive Likelihood Ratio (PLR)
#     <span style="white-space:nowrap

# %% [markdown]
# # Customização dos rótulos

# %%
portuguese_labels = {
    'true_condition': 'Esperado',
    'predicted_condition': 'Predito',
    'positive_predictive_value': 'Precisão',
    'true_positive_rate': 'Recall',
    'true_positive': 'Verdadeiro Positivo',
    'false_positive': 'Falso Positivo',
    'false_negative': 'Falso Negativo',
    'true_negative': 'Verdadeiro Negativo',
    'true_negative_rate': 'Especificidade',
    'false_negative_rate': '<i>Miss Rate</i>',
    'accuracy': 'Acurácia',
    'total_population': 'Total',
    'condition_positive': 'Positivo',
    'condition_negative': 'Negativo',
    'predicted_condition_negative': 'Predito Negativo',
    'predicted_condition_positive': 'Predito Positivo',
    'false_positive_rate': 'Alarme Falso',
    'prevalence': 'Proporção de Positivos'
}

cm = BinaryConfusionMatrix(
    expected=y_test, 
    predicted=lr.predict(X_test),
    labels=portuguese_labels)

HTML(cm.html(
    label=True, acronym=False, legend=False, equation=False,
))
# Out:
#         <table align="center" valign="center" style="text-align:center; border:none; background:transparent;">
#         <tr>
#             <td style="border:none;" colspan="2"></td>
#             <td style="text-align:center;background:#eeeebb;vertical-align: middle" colspan="2">
#                 <b>Esperado</b>
#             </td>
#             <td style="background:none;" colspan="3"></td>
#         </tr>
#         <tr>
#             <td style="border:none;"></td>
#             <td style="background:#dddddd;text-align: center;vertical-align: middle"><b>Total</b> <br/ >99,900</td>
#             <td style="background:#ffffcc;text-align: center;vertical-align: middle"><b>Positivo</b> <br/ >49,957</td>
#             <td style="background:#ddddaa;text-align: center;vertical-align: middle"><b>Negativo</b> <br/ >49,943</td>
#             <td style="background:#eeeecc;text-align: center;vertical-align: middle"><b>Proporção de Positivos</b> <br/ >50.0%</td>
#             <td style="background:#cceecc;border-left:double silver;text-align: center" colspan="2">
#                 <b>Acurácia</b> <br/ >94.3%
#             </td>
#         </tr>
#         <tr>
#             <td style="background:#bbeeee;text-align: center;vertical-align: middle;" rowspan="2">
#                 <b>Predito</b>
#             </td>
#             <td style="background:#ccffff;text-align: center;vertical-align: middle"><b>Predito Positivo</b> <br/ >48,183</td>
#             <td style="background:#ccffcc;text-align: center;vertical-align: middle"><b>Verdadeiro Positivo</b> <br/ >46,201</td>
#             <td style="background:#eedddd;text-align: center;vertical-align: middle"><b>Falso Positivo</b> <br/ >1,982</td>
#             <td style="background:#ccffee;border-top:double silver;text-align: center;vertical-align: middle">
#                 <b>Precisão</b> <br/ >95.9%
#             </td>
#             <td style="background:#cceeff;border-top:double silver;text-align: center" colspan="2">
#                 <b>False Discovery Rate</b> <br/ >4.1%
#             </td>
#         </tr>
#         <tr>
#             <td style="background:#aadddd;text-align: center;vertical-align: middle"><b>Predito Negativo</b> <br/ >51,717</td>
#             <td style="background:#ffdddd;text-align: center;vertical-align: middle"><b>Falso Negativo</b> <br/ >3,756</td>
#             <td style="background:#bbeebb;text-align: center;vertical-align: middle"><b>Verdadeiro Negativo</b> <br/ >47,961</td>
#             <td style="background:#eeddee;border-bottom:double silver;text-align: center;vertical-align: middle">
#                 <b>False Omission Rate</b> <br/ >7.3%
#             </td>
#             <td style="background:#aaddcc;border-bottom:double silver;text-align: center" colspan="2">
#                 <b>Negative Predictive Value</b> <br/ >92.7%
#             </td>
#         </tr>
#         <tr style="font-size:90%;">
#             <td style="border:none;vertical-align:bottom;padding:0 2px 0 0;color:#999999;text-align: center" colspan="2" rowspan="2">
#
#             </td>
#             <td style="background:#eeffcc;text-align: center;vertical-align: middle"><b>Recall</b> <br/ >92.5%</td>
#             <td style="background:#eeddbb;text-align: center;vertical-align: middle"><b>Alarme Falso</b> <br/ >4.0%</td>
#             <td style="background:#eeeeee;text-align: center;vertical-align: middle"><b>Positive Likelihood Ratio</b> <br/ >23.304</td>
#             <td style="background:#dddddd;text-align: center;vertical-align: middle"" rowspan="2">
#                 <b>Diagnostic Odds Ratio</b> <br/ >297.653
#             </td>
#             <td style="background:#ddffdd;border-left:double silver;line-height:2;text-align: center;vertical-align: middle"" rowspan="2">
#                 <b>F<sub>1</sub> score</b> <br/ >94.2%
#             </td>
#         </tr>
#         <tr style="font-size:90%;text-align: center;vertical-align: middle">
#             <td style="background:#ffeecc;text-align: center;vertical-align: middle">
#                 <b><i>Miss Rate</i></b> <br/ >7.5%
#             </td>
#             <td style="background:#ddeebb;text-align: center;vertical-align: middle">
#                 <b>Especificidade</b> <br/ >96.0%
#             </td>
#             <td style="background:#cccccc;text-align: center;vertical-align: middle">
#                 <b>Negative Likelihood Ratio</b> <br/ >0.078
#             </td>
#         </tr>
#         </table>
